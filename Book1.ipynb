# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('test.csv')

# %%
df['diff'] = df['apparent_t'] - df['air_temp']

# %%
df.plot.scatter(x='air_temp', y='diff', c='rel_hum', s=df['wind_spd_kmh']*5, alpha=0.7, figsize=(10, 6))
